# %%
import pandas
import imp
su = imp.load_source('Setup_Datasets', '../Setup_Datasets.py')

# %%
dataset = pandas.read_csv('../../Data/SQL Output/arrests_j1_lemas_acs.csv')
dataset = su.main(dataset)
# Out:
# ../Setup_Datasets.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   'mult_officers', 'u_officers']].sum(axis = 1)
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.py:245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = np.nan
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.py:415: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dataset.columns.unique()
# Out:
# array(['age', 'eyes', 'facility', 'hair', 'height', 'notes', 'ref #',
#        'weight', 'charges', 'id', 'jail_address1', 'jail_address2',
#        'jail_city', 'jail_name', 'jail_state', 'jail_url', 'name',
#        'book_year', 'source', 'arrest_id', 'charges_string', 'source_text',
#        'source_text_clean', 'date', 'state', 'gender', 'race', 'multi',
#        'am_ind', 'hispanic', 'east_asian', 'asian', 'black', 'white',
#        'zipcode', 'population', 'csllea04_id', 'swnauthemp', 'swnftemp',
#        'swnptemp', 'civftemp', 'civptemp', 'ftgangoff', 'ptgangoff',
#        'ftdrugoff', 'ptdrugoff', 'numpatr', 'numinvst', 'w_officers',
#        'b_officers', 'h_officers', 'a_officers', 'n_officers',
#        'ai_officers', 'mult_officers', 'u_officers', 'male_officers',
#        'female_officers', 'totgender', 'opbudget', 'opbudgest', 'drugforf',
#        'gambforf', 'othrforf', 'asforest', 'totacad', 'totfield',
# ...

# %%
dataset[:20]
# Out:
#     age eyes facility hair height    notes                     ref # weight  \
# 0   NaN  NaN      NaN  blk    503  age: 40  55249ed2e4b0ed87a23f3090    110
# 1   NaN  NaN      NaN  bro    502  age: 45  552447c8e4b0ed87a23954fa    150
# 2   NaN  NaN      NaN  bro    607  age: 36  55282ff6e4b0ed87a2710cfe    145
# 3   NaN  NaN      NaN  bro    606  age: 25  55270a06e4b0ed87a260eafb    160
# 4   NaN  NaN      NaN  bro    611  age: 36  5526c6c9e4b0ed87a25bb531    175
# 5   NaN  NaN      NaN  bro    504  age: 26  5524d85ae4b0ed87a23faeef    120
# 6   NaN  NaN      NaN  bro    604  age: 50  5525758ce4b0ed87a249a92c    200
# 7   NaN  NaN      NaN  bro    610  age: 31  5524c978e4b0ed87a23fac3c    125
# 8   NaN  NaN      NaN  bro    603  age: 24  55250095e4b0ed87a241e3e2    283
# 9   NaN  NaN      NaN  gry    503  age: 58  55258bc4e4b0ed87a24ad48c    170
# 10  NaN  NaN      NaN  bro    607  age: 41  5525563de4b0ed87a247d7bd    200
# ...

# %%
dataset.describe()
# Out:
#                age  jail_address2     book_year  multi  am_ind  hispanic  \
# count  6796.000000              0  17038.000000      1      60       469
# mean     34.047675            NaN   2015.017314      1       1         1
# std      36.669690            NaN      1.187279    NaN       0         0
# min     -53.000000            NaN   2013.000000      1       1         1
# 25%      25.000000            NaN   2015.000000      1       1         1
# 50%      31.000000            NaN   2015.000000      1       1         1
# 75%      41.000000            NaN   2015.000000      1       1         1
# max    2032.000000            NaN   2031.000000      1       1         1
#
#        east_asian  asian  black  white         ...           \
# count           5     91   3062   6696         ...
# mean            1      1      1      1         ...
# std             0      0      0      0         ...
# min             1      1      1      1         ...
# ...
